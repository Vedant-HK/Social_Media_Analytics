# %%
#Use APIFY as other method for this

from typing import ItemsView
from googleapiclient.discovery import build
from urllib.parse import urlparse, parse_qs

api_key = 'AIzaSyC1ny-oGUCvdlUq0amYoF07Vp5fM-0k3Go'

def video_comments(video_id_or_url):
    # empty list for storing reply
    replies = []

    # Extract video ID if a URL is provided
    parsed_url = urlparse(video_id_or_url)
    if parsed_url.hostname == 'www.youtube.com' and parsed_url.path == '/watch':
      query_params = parse_qs(parsed_url.query)
      if 'v' in query_params:
        video_id = query_params['v'][0]
      else:
        print("Invalid YouTube URL: No video ID found.")
        return
    elif parsed_url.hostname == 'youtu.be':
      video_id = parsed_url.path[1:] # Remove leading slash
    else:
      video_id = video_id_or_url # Assume it's already just the ID

    # creating youtube resource object
    youtube = build('youtube', 'v3',developerKey=api_key)

    # retrieve youtube video results
    video_response = youtube.commentThreads().list(
        part='snippet,replies',
        videoId=video_id
    ).execute()

    # iterate video response
    while video_response:

      # extracting required info
      # from each result object
      for item in video_response['items']:

        # Extracting comments
        comment = item['snippet']['topLevelComment']['snippet']['textDisplay']

        # counting number of reply of comment
        replycount = item['snippet']['totalReplyCount']

        # if reply is there
        if replycount>0:

          # iterate through all reply
          for reply_item in item['replies']['comments']:

            # Extract reply
            reply_text = reply_item['snippet']['textDisplay']

            # Store reply is list
            replies.append(reply_text)

        # print comment with list of reply
        print(comment, replies, end = '\n\n')

        # empty reply list
        replies = []

      # Again repeat
      if 'nextPageToken' in video_response:
        video_response = youtube.commentThreads().list(
            part = 'snippet,replies',
            videoId = video_id,
            pageToken = video_response['nextPageToken']
          ).execute()
      else:
        break
# Enter video id
video_url = "https://www.youtube.com/watch?v=aEsWltLmPfc"

# Call function
video_comments(video_url)
# Out:
# Media analyst is IT field job or not <br>Please tell me []
#
# Important to know: the funnel is a visual representation of a pattern indicated in the data, not something customers follow linearly. []
#
# Really appreciate the breakdown of different metrics and how they translate into actionable insights for improving our social media strategy. Understanding public sentiment is key, and this video makes it less intimidating. Thanks for sharing this valuable knowledge! []
#
# Really helpful to see how these analytics tools can be applied to real-world scenarios, especially for understanding public sentiment and campaign performance. It&#39;s amazing how much has changed in recognizing the value of social media data! []
#
# Thank you very much. []
#
# thank you for your kindness, Google ['i love the music that google has; it reminds me of the Nintendo Wii days ! so friendly, and universally loved!']
#
# Excellent video []
#
# Insightful and excellent service thanks []
#
# ...
